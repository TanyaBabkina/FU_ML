# %%
import pandas as pd

# %% [markdown]
# 1. Загрузить прилагающийся к работе датасет PRSA_Data

# %%
prsa_data = pd.read_csv("https://raw.githubusercontent.com/koroteevmv/ML_course/main/ML5.2%20numeric%20features/data/PRSA_Data.csv").set_index('Unnamed: 0').reset_index(drop=True)
prsa_data.head()
# Out:
#    No  SO2   NO2     CO         O3    PRES  RAIN   wd  WSPM          AQI Label
# 0   1  6.0  28.0  400.0  51.577659  1023.0   0.0  NNW   4.4  Severely Polluted
# 1   2  6.0  28.0  400.0  50.403851  1023.2   0.0    N   4.7  Severely Polluted
# 2   3 -1.0  19.0  400.0  54.923321  1023.5   0.0  NNW   5.6  Severely Polluted
# 3   4  8.0  14.0   -1.0  -1.000000  1024.5   0.0   NW   3.1          Excellent
# 4   5  9.0  -1.0  300.0  54.296608  1025.2   0.0    N   2.0   Heavily Polluted

# %% [markdown]
# 2. Выведите на экран основную информацию о датасете. Идентифицируйте значения вне разумного диапазона

# %%
prsa_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   No         35064 non-null  int64
#  1   SO2        35064 non-null  float64
#  2   NO2        35064 non-null  float64
#  3   CO         35064 non-null  float64
#  4   O3         35064 non-null  float64
#  5   PRES       35064 non-null  float64
#  6   RAIN       35064 non-null  float64
#  7   wd         35064 non-null  object
#  8   WSPM       35064 non-null  float64
#  9   AQI Label  35064 non-null  object
# dtypes: float64(7), int64(1), object(2)
# memory usage: 2.7+ MB

# %%
# чмсленная статистика
prsa_data.describe()
# Out:
#                  No           SO2           NO2            CO            O3  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000     18.058734     63.236861   1251.121692     45.876835
# std    10122.249256     22.558126     39.109232   1269.033556     54.730861
# min        1.000000     -1.000000     -1.000000     -1.000000     -1.000000
# 25%     8766.750000      4.000000     34.000000    500.000000      2.397428
# 50%    17532.500000     10.000000     58.000000    900.000000     27.356346
# 75%    26298.250000     22.276800     87.000000   1500.000000     69.548316
# max    35064.000000    282.000000    264.000000  10000.000000    363.769133
#
#                PRES          RAIN          WSPM
# count  35064.000000  35064.000000  35064.000000
# mean    1010.520250      0.067653      1.500217
# std       26.289217      0.896833      1.105382
# min       -1.000000     -1.000000     -1.000000
# 25%     1002.500000      0.000000      0.800000
# 50%     1010.800000      0.000000      1.200000
# 75%     1019.400000      0.000000      2.000000
# max     1040.300000     72.500000     11.200000

# %%
import numpy as np

prsa_data[prsa_data == -1] = np.nan
prsa_data.head()
# Out:
#    No  SO2   NO2     CO         O3    PRES  RAIN   wd  WSPM          AQI Label
# 0   1  6.0  28.0  400.0  51.577659  1023.0   0.0  NNW   4.4  Severely Polluted
# 1   2  6.0  28.0  400.0  50.403851  1023.2   0.0    N   4.7  Severely Polluted
# 2   3  NaN  19.0  400.0  54.923321  1023.5   0.0  NNW   5.6  Severely Polluted
# 3   4  8.0  14.0    NaN        NaN  1024.5   0.0   NW   3.1          Excellent
# 4   5  9.0   NaN  300.0  54.296608  1025.2   0.0    N   2.0   Heavily Polluted

# %%
prsa_data.describe()
# Out:
#                  No           SO2           NO2            CO            O3  \
# count  35064.000000  34489.000000  33994.000000  33252.000000  32957.000000
# mean   17532.500000     18.376481     65.258789   1319.353513     48.873754
# std    10122.249256     22.609648     37.996088   1268.114331     55.113576
# min        1.000000      0.285600      1.642400    100.000000     -0.275160
# 25%     8766.750000      4.000000     36.000000    500.000000      3.579219
# 50%    17532.500000     10.000000     60.000000    900.000000     31.945652
# 75%    26298.250000     23.000000     88.000000   1600.000000     72.876079
# max    35064.000000    282.000000    264.000000  10000.000000    363.769133
#
#                PRES          RAIN          WSPM
# count  35044.000000  35044.000000  35050.000000
# mean    1011.097536      0.068263      1.501215
# std       10.355247      0.896726      1.104472
# min      985.900000      0.000000      0.000000
# 25%     1002.500000      0.000000      0.800000
# 50%     1010.800000      0.000000      1.200000
# 75%     1019.400000      0.000000      2.000000
# max     1040.300000     72.500000     11.200000

# %% [markdown]
# 3. Постройте визуализацию распределения каждого численного атрибута.

# %%
import seaborn as sns

sns.histplot(prsa_data.SO2)
# Out:
# <Axes: xlabel='SO2', ylabel='Count'>

# %%
sns.kdeplot(prsa_data.NO2)
# Out:
# <Axes: xlabel='NO2', ylabel='Density'>

# %%
sns.histplot(prsa_data.CO)
# Out:
# <Axes: xlabel='CO', ylabel='Count'>

# %%
sns.histplot(prsa_data.O3)
# Out:
# <Axes: xlabel='O3', ylabel='Count'>

# %%
sns.histplot(prsa_data.PRES)
# Out:
# <Axes: xlabel='PRES', ylabel='Count'>

# %%
sns.histplot(prsa_data.RAIN)
# Out:
# <Axes: xlabel='RAIN', ylabel='Count'>

# %%
sns.histplot(prsa_data.WSPM)
# Out:
# <Axes: xlabel='WSPM', ylabel='Count'>

# %% [markdown]
# 4. Исходя из распределения атрибутов по необходимости примените бинаризацию численных признаков.

# %%
# Катигоризация признака дождь
prsa_data.RAIN[prsa_data.RAIN > 0]
# Out:
# 267      0.1
# 268      0.4
# 269      0.1
# 270      0.9
# 271      0.9
#         ...
# 34891    0.2
# 34892    0.7
# 34893    0.9
# 34894    0.4
# 34895    0.2
# Name: RAIN, Length: 1436, dtype: float64

# %%
is_rain = np.array(prsa_data.RAIN)
is_rain[is_rain > 0] = 1
prsa_data['IS_RAIN'] = is_rain
prsa_data.drop(['RAIN'], axis=1, inplace=True)
prsa_data.describe()
# Out:
#                  No           SO2           NO2            CO            O3  \
# count  35064.000000  34489.000000  33994.000000  33252.000000  32957.000000
# mean   17532.500000     18.376481     65.258789   1319.353513     48.873754
# std    10122.249256     22.609648     37.996088   1268.114331     55.113576
# min        1.000000      0.285600      1.642400    100.000000     -0.275160
# 25%     8766.750000      4.000000     36.000000    500.000000      3.579219
# 50%    17532.500000     10.000000     60.000000    900.000000     31.945652
# 75%    26298.250000     23.000000     88.000000   1600.000000     72.876079
# max    35064.000000    282.000000    264.000000  10000.000000    363.769133
#
#                PRES          WSPM       IS_RAIN
# count  35044.000000  35050.000000  35044.000000
# mean    1011.097536      1.501215      0.040977
# std       10.355247      1.104472      0.198240
# min      985.900000      0.000000      0.000000
# 25%     1002.500000      0.800000      0.000000
# 50%     1010.800000      1.200000      0.000000
# 75%     1019.400000      2.000000      0.000000
# max     1040.300000     11.200000      1.000000

# %% [markdown]
# 5. Постройте совместное распределение каждого признака вместе с целевой переменной. Сделайте вывод о необходимости проведения группировки данных.

# %%
sns.kdeplot(data=prsa_data, x="SO2", hue="AQI Label")
# Out:
# <Axes: xlabel='SO2', ylabel='Density'>

# %%
sns.kdeplot(data=prsa_data, x="NO2", hue="AQI Label", log_scale=True)
# Out:
# <Axes: xlabel='NO2', ylabel='Density'>

# %%
sns.kdeplot(data=prsa_data, x="CO", hue="AQI Label")
# Out:
# <ipython-input-18-0dcfe490e9c4>:1: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(data=prsa_data, x="CO", hue="AQI Label")
# <Axes: xlabel='CO', ylabel='Density'>

# %%
sns.kdeplot(data=prsa_data, x="CO", hue="AQI Label", log_scale=True)
# Out:
# <ipython-input-19-c5b2a0db864b>:1: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(data=prsa_data, x="CO", hue="AQI Label", log_scale=True)
# <Axes: xlabel='CO', ylabel='Density'>

# %%
bin_ranges = [0, 250, 320, 10000]
bin_names = [1, 2, 3]
prsa_data['CO_bin_custom_label'] = pd.cut(np.array(prsa_data['CO']),
                                               bins=bin_ranges, labels=bin_names)
prsa_data.head()
# Out:
#    No  SO2   NO2     CO         O3    PRES   wd  WSPM          AQI Label  \
# 0   1  6.0  28.0  400.0  51.577659  1023.0  NNW   4.4  Severely Polluted
# 1   2  6.0  28.0  400.0  50.403851  1023.2    N   4.7  Severely Polluted
# 2   3  NaN  19.0  400.0  54.923321  1023.5  NNW   5.6  Severely Polluted
# 3   4  8.0  14.0    NaN        NaN  1024.5   NW   3.1          Excellent
# 4   5  9.0   NaN  300.0  54.296608  1025.2    N   2.0   Heavily Polluted
#
#    IS_RAIN CO_bin_custom_label
# 0      0.0                   3
# 1      0.0                   3
# 2      0.0                   3
# 3      0.0                 NaN
# 4      0.0                   2

# %%
prsa_data['CO_bin_custom_label'] = prsa_data['CO_bin_custom_label'].values.add_categories(0)
prsa_data['CO_bin_custom_label'] = prsa_data['CO_bin_custom_label'].fillna(0).astype(int)
prsa_data.head()
# Out:
#    No  SO2   NO2     CO         O3    PRES   wd  WSPM          AQI Label  \
# 0   1  6.0  28.0  400.0  51.577659  1023.0  NNW   4.4  Severely Polluted
# 1   2  6.0  28.0  400.0  50.403851  1023.2    N   4.7  Severely Polluted
# 2   3  NaN  19.0  400.0  54.923321  1023.5  NNW   5.6  Severely Polluted
# 3   4  8.0  14.0    NaN        NaN  1024.5   NW   3.1          Excellent
# 4   5  9.0   NaN  300.0  54.296608  1025.2    N   2.0   Heavily Polluted
#
#    IS_RAIN  CO_bin_custom_label
# 0      0.0                    3
# 1      0.0                    3
# 2      0.0                    3
# 3      0.0                    0
# 4      0.0                    2

# %%
# Группировка значений СО

# %%
bin_ranges = [0, 250, 320, 10000]
bin_names = [1, 2, 3]
prsa_data['CO_bin_custom_label'] = pd.cut(np.array(prsa_data['CO']),
                                               bins=bin_ranges, labels=bin_names)
prsa_data.head()
# Out:
#    No  SO2   NO2     CO         O3    PRES   wd  WSPM          AQI Label  \
# 0   1  6.0  28.0  400.0  51.577659  1023.0  NNW   4.4  Severely Polluted
# 1   2  6.0  28.0  400.0  50.403851  1023.2    N   4.7  Severely Polluted
# 2   3  NaN  19.0  400.0  54.923321  1023.5  NNW   5.6  Severely Polluted
# 3   4  8.0  14.0    NaN        NaN  1024.5   NW   3.1          Excellent
# 4   5  9.0   NaN  300.0  54.296608  1025.2    N   2.0   Heavily Polluted
#
#    IS_RAIN CO_bin_custom_label
# 0      0.0                   3
# 1      0.0                   3
# 2      0.0                   3
# 3      0.0                 NaN
# 4      0.0                   2

# %%
prsa_data['CO_bin_custom_label'] = prsa_data['CO_bin_custom_label'].values.add_categories(0)
prsa_data['CO_bin_custom_label'] = prsa_data['CO_bin_custom_label'].fillna(0).astype(int)
prsa_data.head()
# Out:
#    No  SO2   NO2     CO         O3    PRES   wd  WSPM          AQI Label  \
# 0   1  6.0  28.0  400.0  51.577659  1023.0  NNW   4.4  Severely Polluted
# 1   2  6.0  28.0  400.0  50.403851  1023.2    N   4.7  Severely Polluted
# 2   3  NaN  19.0  400.0  54.923321  1023.5  NNW   5.6  Severely Polluted
# 3   4  8.0  14.0    NaN        NaN  1024.5   NW   3.1          Excellent
# 4   5  9.0   NaN  300.0  54.296608  1025.2    N   2.0   Heavily Polluted
#
#    IS_RAIN  CO_bin_custom_label
# 0      0.0                    3
# 1      0.0                    3
# 2      0.0                    3
# 3      0.0                    0
# 4      0.0                    2

# %% [markdown]
# 5. Удалите или ограничьте экстремальные значения атрибутов.

# %%
prsa_data.PRES[prsa_data.PRES <= 992] = 992
prsa_data.PRES[prsa_data.PRES >= 1034] = 1034
# Out:
# <ipython-input-25-5a60bf876b2e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prsa_data.PRES[prsa_data.PRES <= 992] = 992
# <ipython-input-25-5a60bf876b2e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prsa_data.PRES[prsa_data.PRES >= 1034] = 1034

# %%
sns.histplot(prsa_data.PRES)
# Out:
# <Axes: xlabel='PRES', ylabel='Count'>

# %% [markdown]
# 6. Избавьтесь от пропущенных значений в датасете.

# %%
sns.heatmap(prsa_data.isnull(), yticklabels=False, cbar=False)
# Out:
# <Axes: >

# %%
undef = prsa_data.isnull().sum(axis=1)
undef[undef >= 2].head()
# Out:
# 3      2
# 276    3
# 435    2
# 459    2
# 555    2
# dtype: int64

# %%
prsa_data = prsa_data.drop(undef[undef >= 2].index, axis=0)

# %%
sns.heatmap(prsa_data.isnull(), yticklabels=False, cbar=False)
# Out:
# <Axes: >

# %%
prsa_data.isnull().sum()
# Out:
# No                        0
# SO2                     281
# NO2                     702
# CO                     1028
# O3                     1300
# PRES                      0
# wd                        0
# WSPM                      0
# AQI Label                 0
# IS_RAIN                   0
# CO_bin_custom_label       0
# dtype: int64

# %%
prsa_data.SO2 = prsa_data.SO2.fillna(prsa_data.PRES.mean())

# %%
filler = prsa_data.O3[prsa_data.O3.isna()]

# %%
filler = prsa_data.O3[~prsa_data.O3.isna()].sample(n=len(filler)).set_axis(filler.index)

# %%
prsa_data.O3 = prsa_data.O3.fillna(filler)

# %%
sns.histplot(prsa_data.O3)
# Out:
# <Axes: xlabel='O3', ylabel='Count'>

# %% [markdown]
# 7. При необходимости округлите излишне точные значения атрибутов.

# %%
prsa_data['O3'] = np.array(np.round((prsa_data['O3'])), dtype='int')
prsa_data.head()
# Out:
#    No          SO2   NO2     CO  O3    PRES   wd  WSPM          AQI Label  \
# 0   1     6.000000  28.0  400.0  52  1023.0  NNW   4.4  Severely Polluted
# 1   2     6.000000  28.0  400.0  50  1023.2    N   4.7  Severely Polluted
# 2   3  1011.055986  19.0  400.0  55  1023.5  NNW   5.6  Severely Polluted
# 4   5     9.000000   NaN  300.0  54  1025.2    N   2.0   Heavily Polluted
# 5   6     8.000000  17.0  300.0  54  1025.6    N   3.7   Heavily Polluted
#
#    IS_RAIN  CO_bin_custom_label
# 0      0.0                    3
# 1      0.0                    3
# 2      0.0                    3
# 4      0.0                    2
# 5      0.0                    2

# %% [markdown]
# 8. Рассмотрите возможность преобразования шкалы атрибута к логарифмической.

# %%
prsa_data.SO2 = np.log(prsa_data.SO2)

# %%
sns.histplot(prsa_data.SO2)
# Out:
# <Axes: xlabel='SO2', ylabel='Count'>

# %% [markdown]
# # Самостоятельная работа

# %% [markdown]
# 1) При выполнении 3 и 5 заданий используйте другие методы визуализации. Найдите самый подходящий тип графика для каждого распределения.

# %%
import warnings

def disable_warnings_globally():
  warnings.filterwarnings('ignore', category=Warning)

disable_warnings_globally()

# %%
prsa_data = pd.read_csv("https://raw.githubusercontent.com/koroteevmv/ML_course/main/ML5.2%20numeric%20features/data/PRSA_Data.csv").set_index('Unnamed: 0').reset_index(drop=True)

# %%
prsa_data
# Out:
#           No  SO2   NO2     CO         O3    PRES  RAIN   wd  WSPM  \
# 0          1  6.0  28.0  400.0  51.577659  1023.0   0.0  NNW   4.4
# 1          2  6.0  28.0  400.0  50.403851  1023.2   0.0    N   4.7
# 2          3 -1.0  19.0  400.0  54.923321  1023.5   0.0  NNW   5.6
# 3          4  8.0  14.0   -1.0  -1.000000  1024.5   0.0   NW   3.1
# 4          5  9.0  -1.0  300.0  54.296608  1025.2   0.0    N   2.0
# ...      ...  ...   ...    ...        ...     ...   ...  ...   ...
# 35059  35060  4.0  20.0  300.0  81.053452  1011.9   0.0    N   2.0
# 35060  35061  6.0  55.0  500.0  44.645126  1012.3   0.0  WSW   1.0
# 35061  35062  7.0  48.0  500.0  47.567265  1012.8   0.0    N   1.1
# 35062  35063  5.0  47.0  500.0  49.764297  1012.9   0.0  NNE   1.0
# 35063  35064  6.0  86.0  700.0  11.194135  1012.6   0.0   NE   1.1
#
#                AQI Label
# 0      Severely Polluted
# 1      Severely Polluted
# 2      Severely Polluted
# 3              Excellent
# 4       Heavily Polluted
# ...                  ...
# 35059   Heavily Polluted
# 35060  Severely Polluted
# 35061  Severely Polluted
# 35062  Severely Polluted
# 35063  Severely Polluted
#
# [35064 rows x 10 columns]

# %%
import matplotlib.pyplot as plt

sns.distplot(prsa_data.SO2)
# Out:
# <Axes: xlabel='SO2', ylabel='Density'>

# %%
sns.kdeplot(
   data=prsa_data, x="SO2", hue="AQI Label",color='coolwarm',
   fill=True, common_norm=False,
   alpha=.5, linewidth=0,
)
# Out:
# <Axes: xlabel='SO2', ylabel='Density'>

# %% [markdown]
# Вывод: столбчатая диаграмма подходит лучше всего для визуализации распределения + помогает график, чётче видно распределения
#
# Для визуализации зависимости целевой переменной от признаков подходит kdeplot, так как на одном графике сразу видно информацию по всем целевым признакам

# %% [markdown]
# 2. При выполнении 6 задания мы явно подбирали руками границы диапазона для клиппинга. Реализуйте адаптивный клиппинг через процентили.

# %%
sns.histplot(prsa_data.PRES)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
max = np.percentile(prsa_data.PRES, 99)
min = np.percentile(prsa_data.PRES, 1)
prsa_data.PRES[prsa_data.PRES <= min] = min
prsa_data.PRES[prsa_data.PRES >= max] = max

# %%
sns.histplot(prsa_data.PRES)
# Out:
# <Axes: xlabel='PRES', ylabel='Count'>

# %% [markdown]
# 3. Избавьтесь от оставшихся пропусков в данных. Самостоятельно выберите метод.

# %%
sns.histplot(prsa_data.CO)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import pandas as pd
from sklearn.impute import KNNImputer
imputer = KNNImputer(n_neighbors=5)
prsa_data.CO = imputer.fit_transform(prsa_data.CO.values.reshape(-1, 1))

# %%
sns.histplot(prsa_data.CO)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Заполнение сделанно с помощью импутации по k ближайшим соседям, примечательно, что график распределения визуально почти не изменился повторим визуализацию пропусков, чтобы убедиться, что все значения заполнены и заполним оставшиеся пропуски тем же методом

# %%
sns.heatmap(prsa_data.isnull(), yticklabels=False, cbar=False)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# итоговый датасет с заполнеными значениями
sns.heatmap(prsa_data.isnull(), yticklabels=False, cbar=False)
# Out:
# <Axes: >

# %% [markdown]
# 4. Проведите нормализацию численных признаков. Выберите наиболее подходящий вид нормализации для каждого признака.

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

scaler = MinMaxScaler()
prsa_data.CO = scaler.fit_transform(prsa_data.CO.values.reshape(-1, 1))
prsa_data.NO2 = scaler.fit_transform(prsa_data.NO2.values.reshape(-1, 1))
prsa_data.SO2 = scaler.fit_transform(prsa_data.SO2.values.reshape(-1, 1))
prsa_data.O3 = scaler.fit_transform(prsa_data.O3.values.reshape(-1, 1))

# %%
sns.histplot(prsa_data.CO)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 5. Постройте кореллограмму по всем численным столбцам датасета

# %%
numeric_columns = prsa_data.select_dtypes(include=[np.number]).columns

corr = prsa_data[numeric_columns].corr()

sns.heatmap(corr,
            xticklabels=corr.columns,
            yticklabels=corr.columns,
            annot=True)
plt.show()

# %% [markdown]
# 6. Визуализируйте связи между признаками. Сделайте вывод об их взаимозависимости.

# %%
from scipy.cluster import hierarchy
distance_matrix = 1 - prsa_data[numeric_columns].corr()

dendrogram = hierarchy.linkage(distance_matrix, method='ward')

plt.figure(figsize=(10, 7))
hierarchy.dendrogram(dendrogram, labels=numeric_columns)
plt.show()

# %% [markdown]
# Вывод: мы видим, что есть связь между признаками оранжевого цвета и между признаками зеленого цвета, и две данные группы на более высоком уровне связаны между собой
